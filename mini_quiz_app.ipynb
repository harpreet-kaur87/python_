# %%
print("Welcome to Mini Quiz")
p

questions = {
    '1. What is the capital of India?': {
        'options': ['Chandigarh', 'Delhi', 'Mumbai', 'Hyderabad'],
        'answer': 'Delhi'
    },
    '2. Who is the current prime minister of India?': {
        'options': ['Sonia Gandhi', 'Narender Modi', 'Manmohan Singh', 'Nitin Gadkari'],
        'answer': 'Narender Modi'
    },
    '3. Which city of India is known as city beautiful?': {
        'options': ['Bengaluru', 'Chandigarh', 'Kolkata', 'Shimla'],
        'answer': 'Chandigarh'
    },
    '4. Which planet is known as the Red Planet?': {
        'options': ['Earth', 'Venus', 'Mars', 'Jupiter'],
        'answer': 'Mars'
    },
    '5. What is the national animal of India?': {
        'options': ['Elephant', 'Lion', 'Tiger', 'Leopard'],
        'answer': 'Tiger'
    }
}

score = 0

for ques,ans in questions.items():
    print(ques)
    print()
    for i,option in enumerate(ans['options']):
        print(f'{i+1} : {option}')
    answer = input('Enter your answer - ')
    if answer.lower() == ans['answer'].lower():
        score += 1
        print(f'Your answer is correct and your current score is {score}')
        print()
    else:
        print(f'Your answer is wrong and your current score is {score}')
        print()
print(f'Your final score is {score}')
# Out:
# Welcome to Quiz
# 1. What is the capital of India?
#
# 1 : Chandigarh
# 2 : Delhi
# 3 : Mumbai
# 4 : Hyderabad
# Enter your answer - delhi
# Your answer is correct and your current score is 1
#
# 2. Who is the current prime minister of India?
#
# 1 : Sonia Gandhi
# 2 : Narender Modi
# 3 : Manmohan Singh
# 4 : Nitin Gadkari
# Enter your answer - nitin gadkari
# Your answer is wrong and your current score is 1
#
# 3. Which city of India is known as city beautiful?
#
# 1 : Bengaluru
# 2 : Chandigarh
# 3 : Kolkata
# 4 : Shimla
# Enter your answer - chandigarh
# Your answer is correct and your current score is 2
#
# 4. Which planet is known as the Red Planet?
#
# 1 : Earth
# 2 : Venus
# 3 : Mars
# 4 : Jupiter
# Enter your answer - mars
# Your answer is correct and your current score is 3
#
# 5. What is the national animal of India?
#
# 1 : Elephant
# 2 : Lion
# 3 : Tiger
# 4 : Leopard
# Enter your answer - tiger
# Your answer is correct and your current score is 4
#
# ...
